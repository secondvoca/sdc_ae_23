# %%
import matplotlib.pyplot as plt

from myAE import Manager

import torch
from torch import nn
import torch.nn.functional as F
# Out:
# /home/secondvoca/anaconda3/envs/torch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    loss = ll + kl
    return loss

manager = Manager()
manager.prepare_data()
manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=30)
manager.add_model('vanilla 30')
# Out:
# Now, it is working on cuda:1.
# 100%|██████████| 30/30 [02:48<00:00,  5.60s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = -((pred - x).square() + 1e-6).log().mean()
    loss = ll + kl
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
manager.add_model('pixel_entropy 10')
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:12<00:00,  7.21s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = ((pred - x).square() + 1e-6).log().mean()
    loss = ll + kl
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
manager.add_model('pixel_entropy - 10')
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:12<00:00,  7.21s/it]

# %%
def compare_with_vanilla(manager, name, original_name='vavilla 30'):
    fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])

    manager.swap_current_model(original_name)
    manager.model.to('cpu')
    manager.model.eval()

    for x, y in manager.train_dataloader:
        with torch.no_grad():
            h = manager.model.get_submodule("encoder")(x)
            mu = h[:, :2]
            x_hats = manager.model.get_submodule("decoder")(mu)
        for ax, img in zip(axs1, x[:5]):
            ax.imshow(img.view([28, 28]), cmap='gray', vmin=0, vmax=1)
            ax.axis('off')
        for ax, img in zip(axs2, x_hats):
            ax.imshow(img.view([28, 28]), cmap='gray', vmin=0, vmax=1)
            ax.axis('off')

        
        with torch.no_grad():
            manager.swap_current_model(name)

            manager.model.to('cpu')
            manager.model.eval()

            h = manager.model.get_submodule("encoder")(x)
            mu = h[:, :2]
            x_hats = manager.model.get_submodule("decoder")(mu)
        for ax, img in zip(axs3, x_hats):
            ax.imshow(img.view([28, 28]), cmap='gray', vmin=0, vmax=1)
            ax.axis('off')
        
        break
    plt.tight_layout()

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = (-(pred - 0.5).square() + 0.25).sum()/len(x)
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=30)
name = 'square 30'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:1.
# 100%|██████████| 30/30 [02:55<00:00,  5.85s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 6 in 1
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> name = 'square 30'
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> manager.add_model(name)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> compare_with_vanilla(name)
#
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 6 in 4
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def compare_with_vanilla(name):
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])
# ----> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     manager.swap_current_model('vanilla 10')
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     manager.model.to('cpu')
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     manager.model.eval()
#
# File ~/sdc_ae_23/myAE.py:64, in Manager.swap_current_model(self, name)
#      63 def swap_current_model(self, name):
# ---> 64     self.model = self.models[name]
#
# KeyError: 'vanilla 10'

# %%
compare_with_vanilla(name)

# %% [markdown]
# #### 흐린 데이터는?

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    loss = ll + kl
    return loss

manager_2 = Manager()
manager_2.prepare_data()

# %%
tmp_x = manager_2.training_data[:10]
tmp_x_b = manager_2.training_data[:10].clone() / 2

_, (axs_1, axs_2) = plt.subplots(2, 10, figsize=[20, 4])
for ax, img in zip(axs_1, tmp_x):
    ax.imshow(img.view(28, 28), cmap='gray', vmin=0, vmax=1)
    ax.axis('off')

for ax, img in zip(axs_2, tmp_x_b):
    ax.imshow(img.view(28, 28), cmap='gray', vmin=0, vmax=1)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor

training_data = datasets.MNIST(
            root="data",
            train=True,
            download=True,
            transform=ToTensor(),
        )

class CustomImageDataset(Dataset):
    def __init__(self, x, y):
        self.x = x.view([-1, 1, 28, 28])
        self.y = y 

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

manager_2.training_data_length = len(training_data.data)

manager_2.train_dataloader = DataLoader(
            CustomImageDataset(training_data.data / 255.0 / 2, training_data.targets), batch_size=128, shuffle=True
        )

# %%
training_data.targets.shape
# Out:
# torch.Size([60000])

# %%
print(training_data.data[0].max())
print(training_data.data[0].min())
# Out:
# tensor(0.5000)
# tensor(0.)

# %%
plt.imshow(training_data.data[0], vmax=1, vmin=0)

# %%
_, axs = plt.subplots(1, 5, figsize=[20, 5])

for x, y in manager_2.train_dataloader:
    print(x.shape)
    for ax, img in zip(axs, x[:5]):
        print(img.max())
        print(img.min())
        ax.imshow(img.view([28, 28]), cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    break
# Out:
# torch.Size([128, 28, 28])
# tensor(0.4980)
# tensor(0.)
# tensor(0.5000)
# tensor(0.)
# tensor(0.5000)
# tensor(0.)
# tensor(0.5000)
# tensor(0.)
# tensor(0.4980)
# tensor(0.)

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    loss = ll + kl
    return loss

manager_2.set_default_model(4, 2)

hist = manager_2.train(calc_loss, epochs=30)
manager_2.add_model('vanilla 30 v2')
# Out:
# Now, it is working on cuda:1.
#   0%|          | 0/30 [00:00<?, ?it/s]
# 100%|██████████| 30/30 [01:51<00:00,  3.71s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = (-(pred - 0.5).square() + 0.25).sum()/len(x)
    loss = ll + kl + pe
    return loss

manager_2.set_default_model(4, 2)

hist = manager_2.train(calc_loss, epochs=30)
name = 'square 30 v2'
manager_2.add_model(name)
compare_with_vanilla(name, 'vanilla 30 v2')
# Out:
# Now, it is working on cuda:1.
#   0%|          | 0/30 [00:00<?, ?it/s]
# 100%|██████████| 30/30 [01:58<00:00,  3.94s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 17 in 1
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> name = 'square 30 v2'
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> manager_2.add_model(name)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> compare_with_vanilla(name, 'vanilla 30 v2')
#
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 17 in 4
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def compare_with_vanilla(manager, name, original_name='vavilla 30'):
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])
# ----> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     manager.swap_current_model(original_name)
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     manager.model.to('cpu')
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     manager.model.eval()
#
# AttributeError: 'str' object has no attribute 'swap_current_model'

# %%
compare_with_vanilla(manager_2, name, 'vanilla 30 v2')

# %%
compare_with_vanilla(manager_2, name, 'vanilla 30 v2')

# %% [markdown]
# #### ....

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = (-(pred - 0.5).square() + 0.25).sum()/len(x) * 1.5
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'square 1.5 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:14<00:00,  7.49s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = (-(pred - 0.5).square() + 0.25).sum()/len(x) * 2
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'square 2 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:15<00:00,  7.59s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = (-(pred - 0.5).square() + 0.25).sum()/len(x) * 3
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'square 3 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:15<00:00,  7.54s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = (-(pred - 0.5).square() + 0.25).sum()/len(x) * 10
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'square 10 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:16<00:00,  7.68s/it]

# %%
name = 'vanilla 10'
manager.swap_current_model(name)
manager.plot_generated_images(name)

# %%
name = 'square 10'
manager.swap_current_model(name)
manager.plot_generated_images(name)

# %%
def encode(model, x, y):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    return [mu]

manager.show_latent_space(name, encode)

# %%
name = 'square 1.5 10'
manager.swap_current_model(name)
manager.plot_generated_images(name)

# %%
def encode(model, x, y):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    return [mu]

manager.show_latent_space(name, encode)

# %%
name = 'square 2 10'
manager.swap_current_model(name)
manager.plot_generated_images(name)

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    pe = ((pred * 4 * math.pi - math.pi / 2).sin() + 1).sum()/len(x)
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'sin 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
# 100%|██████████| 10/10 [01:15<00:00,  7.59s/it]

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    ms = (pred - x).square()
    pe = -ms[ms > 0.5].log().sum()
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'pe 0.5 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [01:33<00:00,  9.31s/it]

# %%
tmp = torch.rand(10, 1, 5, 7)
torch.div(tmp, tmp.sum(dim=[1,2,3]).view([-1, 1]))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 11 in 2
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tmp = torch.rand(10, 1, 5, 7)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> torch.div(tmp, tmp.sum(dim=[1,2,3]).view([-1, 1]))
#
# RuntimeError: The size of tensor a (5) must match the size of tensor b (10) at non-singleton dimension 2

# %%
def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    ms = (pred - x).square()
    msm = ms / ms.sum(dim=[1, 2, 3])
    pe = -msm.log().sum()
    loss = ll + kl + pe
    return loss

manager.set_default_model(4, 2)

hist = manager.train(calc_loss, epochs=10)
name = 'pe prop 10'
manager.add_model(name)
compare_with_vanilla(name)
# Out:
# Now, it is working on cuda:0.
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 12 in 1
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>     return loss
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> manager.set_default_model(4, 2)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> hist = manager.train(calc_loss, epochs=10)
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> name = 'pe prop 10'
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> manager.add_model(name)
#
# File ~/sdc_ae_23/myAE.py:191, in Manager.train(self, calc_loss, epochs)
#     188 hist = torch.zeros(0)
#     190 for _ in tqdm(range(epochs)):
# --> 191     tmp = self.run(
#     192         self.model, self.train_dataloader, self.optimizer, device, calc_loss
#     193     )
#     194     hist = torch.cat([hist, tmp])
#     196 return hist
#
# File ~/sdc_ae_23/myAE.py:167, in Manager.run(self, model, dataloader, optimizer, device, calc_loss)
#     164 y = y.to(device)
#     166 # Compute prediction error
# --> 167 loss = calc_loss(model, x, y, F, device=device)
#     169 # Backpropagation
#     170 loss.backward()
#
# /home/secondvoca/sdc_ae_23/anormaly.ipynb Cell 12 in 1
#       <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> ms = (pred - x).square()
# ---> <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> msm = ms / ms.sum(dim=[1, 2, 3])
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> pe = -msm.log().sum()
#      <a href='vscode-notebook-cell://ssh-remote%2Ba101/home/secondvoca/sdc_ae_23/anormaly.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> loss = ll + kl + pe
#
# RuntimeError: The size of tensor a (28) must match the size of tensor b (128) at non-singleton dimension 3

# %%
fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])

manager.swap_current_model('vanilla 10')
manager.model.to('cpu')
manager.model.eval()

for x, y in manager.train_dataloader:
    with torch.no_grad():
        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs1, x[:5]):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    for ax, img in zip(axs2, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')

    
    with torch.no_grad():
        manager.swap_current_model('pixel_entropy - 10')

        manager.model.to('cpu')
        manager.model.eval()

        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs3, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    
    break
plt.tight_layout()

# %%
fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])

manager.swap_current_model('vanilla 10')
manager.model.to('cpu')
manager.model.eval()

for x, y in manager.train_dataloader:
    with torch.no_grad():
        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs1, x[:5]):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    for ax, img in zip(axs2, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')

    
    with torch.no_grad():
        manager.swap_current_model('vanilla 10')

        manager.model.to('cpu')
        manager.model.eval()

        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs3, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    
    break
plt.tight_layout()

# %%
fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])

manager.model.to('cpu')
manager.model.eval()

for x, y in manager.train_dataloader:
    with torch.no_grad():
        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs1, x[:5]):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    for ax, img in zip(axs2, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')

    
    with torch.no_grad():
        manager.swap_current_model('vanilla')

        manager.model.to('cpu')
        manager.model.eval()

        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs3, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    
    break
plt.tight_layout()

# %%
fig, (axs1, axs2, axs3) = plt.subplots(nrows=3, ncols=5, figsize=[20, 13])

manager.model.to('cpu')
manager.model.eval()

for x, y in manager.train_dataloader:
    with torch.no_grad():
        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs1, x[:5]):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    for ax, img in zip(axs2, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')

    manager.model.to('cpu')
    manager.model.eval()

    with torch.no_grad():
        manager.swap_current_model('vanilla')
        h = manager.model.get_submodule("encoder")(x)
        mu = h[:, :2]
        x_hats = manager.model.get_submodule("decoder")(mu)
    for ax, img in zip(axs3, x_hats):
        ax.imshow(img.view([28, 28]))
        ax.axis('off')
    
    break
plt.tight_layout()

# 10 epochs

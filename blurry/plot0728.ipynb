# %%
import torch
import matplotlib.pyplot as plt

# %%
x = torch.tensor([0, 1, 2], dtype=torch.float)
y = torch.tensor([0, 1, 0], dtype=torch.float)

plt.scatter(x, y)

lx = torch.linspace(-0.25, 2.25, 100)
l1y = torch.zeros(100)
l2y = torch.ones(100) * 1 / 3
l3y = -(lx - 1)**2 + 1

plt.plot(lx, l1y, color='#f00a')
plt.plot(lx, l2y, color='#00fa')
# plt.plot(lx, l3y, color='#0f0a')

plt.xlim([-0.5, 2.5])
plt.ylim([-0.5, 1.5])
plt.show()

# %%
(1 - x)**2 + 2*x**2

# %%
from myAE import Manager
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F
# Out:
# /home/secondvoca/anaconda3/envs/torch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
manager = Manager()
manager.prepare_data()

def calc_loss(model, x, y, F, device):
    h = model.get_submodule("encoder")(x)
    mu = h[:, :2]
    log_sigma = h[:, 2:4]
    sigma = log_sigma.exp()
    z = torch.rand_like(mu, device=device) * sigma + mu
    pred = model.get_submodule("decoder")(z)
    kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
    ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
    loss = ll + kl
    return loss

manager.set_default_model(4, 2)

# %%
hist = manager.train_on_cpu(calc_loss, epochs=30)
# Out:
# Now, it is working on cpu.
# 100%|██████████| 30/30 [05:07<00:00, 10.26s/it]

# %%
manager.plot_generated_images('base 2d, 30 epochs')

# %%
from torch import nn
from collections import OrderedDict

class My_Encoder(nn.Module):
    def __init__(self, dim_input, dim_encoder_output=2, activation="tanh"):
        super().__init__()

        if activation == "tanh":
            self.activation = torch.tanh
        elif activation == "sigmoid":
            self.activation = torch.sigmoid
        elif activation == "relu":
            self.activation = torch.relu

        self.l0 = nn.Linear(dim_input, 512)
        self.l1 = nn.Linear(512, 512)
        self.l2 = nn.Linear(512, dim_encoder_output)

    def forward(self, x):
        h = self.activation(self.l0(x))
        h = self.activation(self.l1(h))
        z = self.l2(h)
        return z


class My_Decoder(nn.Module):
    def __init__(self, dim_decoder_input, activation="tanh"):
        super().__init__()

        if activation == "tanh":
            self.activation = torch.tanh
        elif activation == "sigmoid":
            self.activation = torch.sigmoid
        elif activation == "relu":
            self.activation = torch.relu

        self.l0 = nn.Linear(dim_decoder_input, 512)
        self.l1 = nn.Linear(512, 512)
        self.l2 = nn.Linear(512, 784)
        self.unfln = nn.Unflatten(1, [1, 28, 28])

    def forward(self, z):
        x_hat = self.activation(self.l0(z))
        x_hat = self.activation(self.l1(x_hat))
        x_hat = torch.sigmoid(self.l2(x_hat))
        x_hat = self.unfln(x_hat)
        return x_hat

# %%
# make another network for 1 dimensionality and conditioned inputs
model = nn.Sequential(
    OrderedDict(
        [
            ("encoder", My_Encoder(784 + 2)), # with 2 condition -> mu and sigma out
            ("decoder", My_Decoder(3)),       # with 2 condition <- sample + 2
        ]
    )
)
optimizer = torch.optim.Adam(model.parameters())

# %%
from tqdm import tqdm

for _ in tqdm(range(30)):
    for x, y in manager.train_dataloader:
        # get condition from the base model
        with torch.no_grad():
            condition = manager.model.get_submodule('encoder')(x)[:, :2] # with no sampling
        
        # flatten the input data
        x_flat = x.view(len(x), -1)

        # concat the condition and data
        x_condi_flat = torch.cat([condition, x_flat], dim=1)

        # run encoder
        h = model.get_submodule('encoder')(x_condi_flat)

        # sampling
        mu = h[:, :1]
        log_sigma = h[:, 1:]
        sigma = log_sigma.exp()
        z = torch.rand_like(mu) * sigma + mu

        # concat the condition and sample point
        z_condi = torch.cat([condition, z], dim=1)

        # run decoder
        pred = model.get_submodule("decoder")(z_condi)

        # calc recon loss and kl divergence
        kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
        ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
        loss = ll + kl

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# 100%|██████████| 30/30 [05:26<00:00, 10.89s/it]

# %%
def get_tx(points):
    bases = []
    for p in points:
        bases.append(torch.ones(10, 1) * p)

    b = torch.linspace(-3, 3, 10).view(-1, 1)
    tx = torch.cat([*bases, b], dim=1)
    return tx


def show_ten_images(title, imgs):
    tmp = torch.zeros(28 * 10, 28)

    for idx, img in enumerate(imgs):
        tmp[idx * 28: (idx + 1) * 28, :28] = img.view(28, 28)
    
    plt.figure(figsize=(3, 15))
    plt.imshow(tmp, cmap='gray')
    plt.title(title, fontdict={'fontsize':20})
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
position = [0, 0]

tx = get_tx(position)

with torch.no_grad():
    pred = model.get_submodule('decoder')(tx)

show_ten_images(str(position), pred)

# %%
position = [0, -2]

tx = get_tx(position)

with torch.no_grad():
    pred = model.get_submodule('decoder')(tx)

show_ten_images(str(position), pred)

# %%
position = [0, 2]

tx = get_tx(position)

with torch.no_grad():
    pred = model.get_submodule('decoder')(tx)

show_ten_images(str(position), pred)

# %%
position = [-2, 0]

tx = get_tx(position)

with torch.no_grad():
    pred = model.get_submodule('decoder')(tx)

show_ten_images(str(position), pred)

# %%
position = [2, 0]

tx = get_tx(position)

with torch.no_grad():
    pred = model.get_submodule('decoder')(tx)

show_ten_images(str(position), pred)

# %%
model_2 = nn.Sequential(
    OrderedDict(
        [
            ("encoder", My_Encoder(784 + 3)), 
            ("decoder", My_Decoder(4)),
        ]
    )
)
optimizer_2 = torch.optim.Adam(model_2.parameters())

# %%
from tqdm import tqdm

for _ in tqdm(range(30)):
    for x, y in manager.train_dataloader:
        # get condition from the base model
        with torch.no_grad():
            condition = manager.model.get_submodule('encoder')(x)[:, :2] # with no sampling

        # flatten the input data
        x_flat = x.view(len(x), -1)

        # concat the condition and data
        x_condi_flat = torch.cat([condition, x_flat], dim=1)

        # get second condition
        with torch.no_grad():
            condition_2 = model.get_submodule('encoder')(x_condi_flat)[:, :1]

        x_condi_flat_condi2 = torch.cat([x_condi_flat, condition_2], dim=1)

        # run encoder
        h = model_2.get_submodule('encoder')(x_condi_flat_condi2)

        # sampling
        mu = h[:, :1]
        log_sigma = h[:, 1:]
        sigma = log_sigma.exp()
        z = torch.rand_like(mu) * sigma + mu

        # concat the conditions and sample point
        z_condi = torch.cat([condition, condition_2, z], dim=1) # condition 2 appeared

        # run decoder
        pred = model_2.get_submodule("decoder")(z_condi)

        # calc recon loss and kl divergence
        kl = 0.5*(mu.square() + sigma.square() - log_sigma - 1).sum(dim=1).mean()
        ll = F.binary_cross_entropy(pred, x, reduction='sum')/len(x)
        loss = ll + kl

        optimizer_2.zero_grad()
        loss.backward()
        optimizer_2.step()
# Out:
# 100%|██████████| 30/30 [07:00<00:00, 14.02s/it]

# %%
def show_ten_images_hori(title, imgs):
    tmp = torch.zeros(28, 28 * 10)

    for idx, img in enumerate(imgs):
        tmp[:28, idx * 28: (idx + 1) * 28] = img.view(28, 28)
    
    plt.figure(figsize=(20, 3))
    plt.imshow(tmp, cmap='gray')
    plt.title(title, fontdict={'fontsize':20})
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
position = [0, 0, 0]

tx = get_tx(position)

with torch.no_grad():
    pred = model_2.get_submodule('decoder')(tx)

show_ten_images_hori(str(position), pred)

# %%
position = [0, 0, -2]

tx = get_tx(position)

with torch.no_grad():
    pred = model_2.get_submodule('decoder')(tx)

show_ten_images_hori(str(position), pred)

# %%
position = [0, 0, -1]

tx = get_tx(position)

with torch.no_grad():
    pred = model_2.get_submodule('decoder')(tx)

show_ten_images_hori(str(position), pred)

# %%
position = [0, 0, 1]

tx = get_tx(position)

with torch.no_grad():
    pred = model_2.get_submodule('decoder')(tx)

show_ten_images_hori(str(position), pred)

# %%
position = [0, 0, 2]

tx = get_tx(position)

with torch.no_grad():
    pred = model_2.get_submodule('decoder')(tx)

show_ten_images_hori(str(position), pred)

# %%
img = torch.zeros(28 * 11, 28 * 11)

a = torch.linspace(-3, 3, 11)
b = torch.linspace(3, -3, 11)
for c, pa in enumerate(a):
    for r, pb in enumerate(b):
        latent = torch.cat([pa.view(1, 1), pb.view(1, 1), torch.zeros(1, 2)], dim=1)
        with torch.no_grad():
            tmp = model_2.get_submodule('decoder')(latent)
        img[28 * r:28 * (r + 1), 28 * c:28 * (c + 1)] = tmp.view(28, 28)

plt.figure(figsize=(9, 9))
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title('4 dim')
plt.show()

# %%
# 그냥 4차원으로 훈련한 데이터와의 비교
